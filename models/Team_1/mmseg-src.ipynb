# %%
# CUDAのバージョンを確認: Cuda compilation tools, release 11.0, V11.0.221　-> バージョンはCUDA11.0
# !nvcc -V
# Check GCC version: (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
# !gcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0
# gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
# Copyright (C) 2019 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !pip download pip
# !pip download torch==1.10.0+cu111 torchvision==0.11.0+cu111 torchaudio==0.10.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 18.3 MB/s eta 0:00:0000:0100:01
# Saved ./pip-22.2.2-py3-none-any.whl
# Successfully downloaded pip
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 GB 515.6 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.9/21.9 MB 49.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 66.0 MB/s eta 0:00:00:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 67.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 63.6 MB/s eta 0:00:00:00:01
# Saved ./torch-1.10.0+cu111-cp37-cp37m-linux_x86_64.whl
# Saved ./torchvision-0.11.0+cu111-cp37-cp37m-linux_x86_64.whl
# Saved ./torchaudio-0.10.0+rocm4.1-cp37-cp37m-linux_x86_64.whl
# Saved ./Pillow-9.2.0-cp37-cp37m-manylinux_2_28_x86_64.whl
# ...

# %%
cu_version='cu111'
torch_version='torch1.10'

# !pip download mmcv-full==1.6.0 -f https://download.openmmlab.com/mmcv/dist/{cu_version}/{torch_version}/index.html
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu111/torch1.10/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 MB 6.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.3/596.3 kB 9.7 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 21.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.2/190.2 kB 17.0 MB/s eta 0:00:00
# ...
#   File was already downloaded /kaggle/working/Pillow-9.2.0-cp37-cp37m-manylinux_2_28_x86_64.whl
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 4.4 MB/s eta 0:00:00
# ...
#   File was already downloaded /kaggle/working/numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 8.1 MB/s eta 0:00:00
# Saved ./mmcv_full-1.6.0-cp37-cp37m-manylinux1_x86_64.whl
# Saved ./opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ...

# %%
# !git clone https://github.com/ykawa2/mmsegmentation.git
# %cd mmsegmentation

# !pip download mmsegmentation
# Out:
# Cloning into 'mmsegmentation'...
# remote: Enumerating objects: 7834, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 7834 (delta 25), reused 39 (delta 15), pack-reused 7772
# Receiving objects: 100% (7834/7834), 13.56 MiB | 33.63 MiB/s, done.
# Resolving deltas: 100% (5792/5792), done.
# /kaggle/working/mmsegmentation
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.7/821.7 kB 13.0 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 75.9 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached packaging-21.3-py3-none-any.whl (40 kB)
# ...
#   Using cached numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.8/647.8 kB 44.2 MB/s eta 0:00:00
# ...
#   Using cached Pillow-9.2.0-cp37-cp37m-manylinux_2_28_x86_64.whl (3.2 MB)
# ...
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# ...

# %%
# %cd /kaggle/working
# !mkdir src
# !mv *.whl src
# Out:
# /kaggle/working

# %%
# 2022/9/8
# %cd src
# !rm Pillow*
# !pip download pillow==7.1.2
# Out:
# /kaggle/working/src
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 21.7 MB/s eta 0:00:0000:010:01
# Saved ./Pillow-7.1.2-cp37-cp37m-manylinux1_x86_64.whl
# Successfully downloaded pillow
